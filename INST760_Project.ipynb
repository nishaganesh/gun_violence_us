# %%
#load the file
import os
import pandas as pd

# %%
script_dir = os.getcwd()
file = 'gun-violence-data_01-2013_03-2018.csv'
gun_violence = pd.read_csv(os.path.normcase(os.path.join(script_dir, file)))

#get the number of rows and columns
gun_violence.shape
# Out:
# (239677, 29)

# %%
# added the missing Las Vegas Incident  https://www.kaggle.com/jameslko/gun-violence-data/discussion/55307
missing_incident = ['sban_1', '2017-10-01', 'Nevada', 'Las Vegas', 'Mandalay Bay 3950 Blvd S', 59, 489, 'https://en.wikipedia.org/wiki/2017_Las_Vegas_shooting', 'https://en.wikipedia.org/wiki/2017_Las_Vegas_shooting', '-', '-', '-', '-', '-', '36.095', 'Hotel', 
               '-115.171667', 47, 'Route 91 Harvest Festiva; concert, open fire from 32nd floor. 47 guns seized; TOTAL:59 kill, 489 inj, number shot TBD,girlfriend Marilou Danley POI', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
gun_violence.loc[len(gun_violence)] = missing_incident

#get the number of rows and columns
gun_violence.shape
# Out:
# (239678, 29)

# %%
#top 10 rows of the dataset
gun_violence.head()
# Out:
#   incident_id        date           state city_or_county  \
# 0      461105  2013-01-01    Pennsylvania     Mckeesport
# 1      460726  2013-01-01      California      Hawthorne
# 2      478855  2013-01-01            Ohio         Lorain
# 3      478925  2013-01-05        Colorado         Aurora
# 4      478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
#bottom ten rows of the dataset
gun_violence.tail()
# Out:
#        incident_id        date      state city_or_county  \
# 239673     1083139  2018-03-31  Louisiana   Natchitoches
# 239674     1083151  2018-03-31  Louisiana         Gretna
# 239675     1082514  2018-03-31      Texas        Houston
# 239676     1081940  2018-03-31      Maine   Norridgewock
# 239677      sban_1  2017-10-01     Nevada      Las Vegas
#
#                           address  n_killed  n_injured  \
# 239673             247 Keyser Ave         1          0
# 239674  1300 block of Cook Street         0          1
# 239675     12630 Ashford Point Dr         1          0
# 239676           434 Skowhegan Rd         2          0
# 239677   Mandalay Bay 3950 Blvd S        59        489
#
#                                              incident_url  \
# 239673  http://www.gunviolencearchive.org/incident/108...
# 239674  http://www.gunviolencearchive.org/incident/108...
# 239675  http://www.gunviolencearchive.org/incident/108...
# ...

# %%
#descriptive statistics
gun_violence.describe()
# Out:
#             n_killed      n_injured  n_guns_involved
# count  239678.000000  239678.000000    140227.000000
# mean        0.252535       0.496045         1.372767
# std         0.535399       1.236321         4.679772
# min         0.000000       0.000000         1.000000
# 25%         0.000000       0.000000         1.000000
# 50%         0.000000       0.000000         1.000000
# 75%         0.000000       1.000000         1.000000
# max        59.000000     489.000000       400.000000

# %%
#get the variable names
gun_violence.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
#get the number of observations for each variable
gun_violence.count()
# Out:
# incident_id                    239678
# date                           239678
# state                          239678
# city_or_county                 239678
# address                        223181
# n_killed                       239678
# n_injured                      239678
# incident_url                   239678
# source_url                     239210
# incident_url_fields_missing    239678
# congressional_district         227734
# gun_stolen                     140180
# gun_type                       140227
# incident_characteristics       239352
# latitude                       231755
# location_description            42090
# longitude                      231755
# n_guns_involved                140227
# notes                          158661
# participant_age                147380
# participant_age_group          197559
# participant_gender             203316
# participant_name               117425
# participant_relationship        15775
# participant_status             212052
# ...

# %%
#finding the percentage of missing values
missing_rows = gun_violence.isnull().sum()/gun_violence.shape[0]
missing_rows
# Out:
# incident_id                    0.000000
# date                           0.000000
# state                          0.000000
# city_or_county                 0.000000
# address                        0.068830
# n_killed                       0.000000
# n_injured                      0.000000
# incident_url                   0.000000
# source_url                     0.001953
# incident_url_fields_missing    0.000000
# congressional_district         0.049834
# gun_stolen                     0.415132
# gun_type                       0.414936
# incident_characteristics       0.001360
# latitude                       0.033057
# location_description           0.824389
# longitude                      0.033057
# n_guns_involved                0.414936
# notes                          0.338024
# participant_age                0.385092
# participant_age_group          0.175732
# participant_gender             0.151712
# participant_name               0.510072
# ...

# %%
gun_violence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239678 entries, 0 to 239677
# Data columns (total 29 columns):
# incident_id                    239678 non-null object
# date                           239678 non-null object
# state                          239678 non-null object
# city_or_county                 239678 non-null object
# address                        223181 non-null object
# n_killed                       239678 non-null int64
# n_injured                      239678 non-null int64
# incident_url                   239678 non-null object
# source_url                     239210 non-null object
# incident_url_fields_missing    239678 non-null object
# congressional_district         227734 non-null object
# gun_stolen                     140180 non-null object
# gun_type                       140227 non-null object
# incident_characteristics       239352 non-null object
# latitude                       231755 non-null object
# ...

# %%
gun_violence.head()
# Out:
#   incident_id        date           state city_or_county  \
# 0      461105  2013-01-01    Pennsylvania     Mckeesport
# 1      460726  2013-01-01      California      Hawthorne
# 2      478855  2013-01-01            Ohio         Lorain
# 3      478925  2013-01-05        Colorado         Aurora
# 4      478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
#convert number of guns involved to numeric - it shouldn't be float
gun_violence['n_guns_involved'] = gun_violence['n_guns_involved'].fillna(-1).astype(int)

#convert congressional_district, state_house_district, state_senate_district to objects
gun_violence[['congressional_district', 'state_house_district', 'state_senate_district']] = gun_violence[['congressional_district', 'state_house_district', 'state_senate_district']].astype(object)
gun_violence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239678 entries, 0 to 239677
# Data columns (total 29 columns):
# incident_id                    239678 non-null object
# date                           239678 non-null object
# state                          239678 non-null object
# city_or_county                 239678 non-null object
# address                        223181 non-null object
# n_killed                       239678 non-null int64
# n_injured                      239678 non-null int64
# incident_url                   239678 non-null object
# source_url                     239210 non-null object
# incident_url_fields_missing    239678 non-null object
# congressional_district         227734 non-null object
# gun_stolen                     140180 non-null object
# gun_type                       140227 non-null object
# incident_characteristics       239352 non-null object
# latitude                       231755 non-null object
# ...

# %%
gun_violence.head()
# Out:
#   incident_id        date           state city_or_county  \
# 0      461105  2013-01-01    Pennsylvania     Mckeesport
# 1      460726  2013-01-01      California      Hawthorne
# 2      478855  2013-01-01            Ohio         Lorain
# 3      478925  2013-01-05        Colorado         Aurora
# 4      478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
# creating month, year, weekday, week and quarter column
gun_violence['date'] = pd.to_datetime(gun_violence['date'])
gun_violence['year'] = gun_violence['date'].dt.year
gun_violence['month'] = gun_violence['date'].dt.month
gun_violence['weekday'] = gun_violence['date'].dt.weekday
gun_violence['week'] = gun_violence['date'].dt.week
gun_violence['quarter'] = gun_violence['date'].dt.quarter
gun_violence['killed_injured'] = gun_violence['n_killed'] + gun_violence['n_injured']

# %%
gun_violence.head()
# Out:
#   incident_id       date           state city_or_county  \
# 0      461105 2013-01-01    Pennsylvania     Mckeesport
# 1      460726 2013-01-01      California      Hawthorne
# 2      478855 2013-01-01            Ohio         Lorain
# 3      478925 2013-01-05        Colorado         Aurora
# 4      478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
gun_violence["participant_gender"] = gun_violence["participant_gender"].fillna("0::Unknown")


def clean_participant_gender(row) :
    gender_row_values = []
    gender_row = str(row).split("||")
    for x in gender_row :
        gender_row_value = str(x).split("::")
        if len(gender_row_value) > 1 :
            gender_row_values.append(gender_row_value[1])
            
    return gender_row_values


participant_genders = gun_violence.participant_gender.apply(clean_participant_gender)
gun_violence["participant_gender_total"] = participant_genders.apply(lambda x: len(x))
gun_violence["participant_gender_male"] = participant_genders.apply(lambda x: x.count("Male"))
gun_violence["participant_gender_female"] = participant_genders.apply(lambda x: x.count("Female"))
gun_violence["participant_gender_unknown"] = participant_genders.apply(lambda x: x.count("Unknown"))
del(participant_genders)

# %%
gun_violence.head()
# Out:
#   incident_id       date           state city_or_county  \
# 0      461105 2013-01-01    Pennsylvania     Mckeesport
# 1      460726 2013-01-01      California      Hawthorne
# 2      478855 2013-01-01            Ohio         Lorain
# 3      478925 2013-01-05        Colorado         Aurora
# 4      478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
gun_violence["n_guns_involved"] = gun_violence["n_guns_involved"].fillna(0)
gun_violence["gun_stolen"] = gun_violence["gun_stolen"].fillna("0::Unknown")
# Prints a lot but gives all the unique values of a column
#dataset_gunviolence["gun_stolen"].unique()

def clean_gun_stolen(row) :
    unknownCount = 0
    stolenCount = 0
    notstolenCount = 0
    gunstolen_row_values = []
    
    gunstolen_row = str(row).split("||")
    for x in gunstolen_row :
            gunstolen_row_value = str(x).split("::")
            if len(gunstolen_row_value) > 1 :
                gunstolen_row_values.append(gunstolen_row_value[1])
                if "Stolen" in gunstolen_row_value :
                    stolenCount += 1
                elif "Not-stolen" in gunstolen_row_value :
                    notstolenCount += 1
                else :
                    unknownCount += 1
                    
    return gunstolen_row_values


gunstolenvalues = gun_violence.gun_stolen.apply(clean_gun_stolen)
gun_violence["gun_stolen_stolen"] = gunstolenvalues.apply(lambda x: x.count("Stolen"))
gun_violence["gun_stolen_notstolen"] = gunstolenvalues.apply(lambda x: x.count("Not-stolen"))
del(gunstolenvalues)

# %%
gun_violence.head()
# Out:
#   incident_id       date           state city_or_county  \
# 0      461105 2013-01-01    Pennsylvania     Mckeesport
# 1      460726 2013-01-01      California      Hawthorne
# 2      478855 2013-01-01            Ohio         Lorain
# 3      478925 2013-01-05        Colorado         Aurora
# 4      478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
#gun_violence.participant_age_group.unique()
gun_violence["participant_age_group"] = gun_violence["participant_age_group"].fillna("0::Unknown")

def clean_participant_age_group(row) :
    unknownCount = 0
    childCount = 0
    teenCount = 0
    adultCount = 0
    agegroup_row_values = []
    
    agegroup_row = str(row).split("||")
    for x in agegroup_row :
        agegroup_row_value = str(x).split("::")
        if len(agegroup_row_value) > 1 :
            agegroup_row_values.append(agegroup_row_value[1])
            if "Child 0-11" in agegroup_row_value :
                childCount += 1
            elif "Teen 12-17" in agegroup_row_value :
                teenCount += 1
            elif "Adult 18+" in agegroup_row_value :
                adultCount += 1
            else :
                unknownCount += 1
                
    return agegroup_row_values

agegroupvalues = gun_violence.participant_age_group.apply(clean_participant_age_group)
gun_violence["agegroup_child"] = agegroupvalues.apply(lambda x: x.count("Child 0-11"))
gun_violence["agegroup_teen"] = agegroupvalues.apply(lambda x: x.count("Teen 12-17"))
gun_violence["agegroup_adult"] = agegroupvalues.apply(lambda x: x.count("Adult 18+"))
del(agegroupvalues)

# %%
gun_violence.head()
# Out:
#   incident_id       date           state city_or_county  \
# 0      461105 2013-01-01    Pennsylvania     Mckeesport
# 1      460726 2013-01-01      California      Hawthorne
# 2      478855 2013-01-01            Ohio         Lorain
# 3      478925 2013-01-05        Colorado         Aurora
# 4      478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
gun_violence["state"].value_counts()
# Out:
# Illinois                17556
# California              16306
# Florida                 15029
# Texas                   13577
# Ohio                    10244
# New York                 9712
# Pennsylvania             8929
# Georgia                  8925
# North Carolina           8739
# Louisiana                8103
# Tennessee                7626
# South Carolina           6939
# Missouri                 6631
# Michigan                 6136
# Massachusetts            5981
# Virginia                 5949
# Indiana                  5852
# Maryland                 5798
# Alabama                  5471
# New Jersey               5387
# Wisconsin                4787
# Kentucky                 4157
# Mississippi              3599
# Oklahoma                 3455
# Washington               3434
# Colorado                 3201
# District of Columbia     3195
# Connecticut              3067
# Arkansas                 2842
# Iowa                     2517
# Minnesota                2408
# ...

# %%
#exporting cleaned dataset to a new_file
from pandas import DataFrame
df = DataFrame(gun_violence)

export_csv = df.to_csv (r'/Users/nisha/UMD/INST760/Project/gun_violence_cleaned_final.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

print (df)
# Out:
#        incident_id       date           state city_or_county  \
# 0           461105 2013-01-01    Pennsylvania     Mckeesport
# 1           460726 2013-01-01      California      Hawthorne
# 2           478855 2013-01-01            Ohio         Lorain
# 3           478925 2013-01-05        Colorado         Aurora
# 4           478959 2013-01-07  North Carolina     Greensboro
# ...            ...        ...             ...            ...
# 239673     1083139 2018-03-31       Louisiana   Natchitoches
# 239674     1083151 2018-03-31       Louisiana         Gretna
# 239675     1082514 2018-03-31           Texas        Houston
# 239676     1081940 2018-03-31           Maine   Norridgewock
# 239677      sban_1 2017-10-01          Nevada      Las Vegas
#
#                                           address  n_killed  n_injured  \
# 0       1506 Versailles Avenue and Coursin Street         0          4
# 1                    13500 block of Cerise Avenue         1          3
# ...

# %%
import nltk

# Columns to be split and parsed
parsed_columns = ['gun_stolen', 'gun_type', 'incident_characteristics', 'participant_age', 'participant_age_group', 'participant_gender', 'participant_name', 'participant_status', 'participant_type']

# %%
gun_violence['gun_stolen_parsed'] = gun_violence['gun_stolen'].str.replace('\|\|', ', ')
gun_violence['gun_stolen_parsed']

gun_violence['gun_stolen_parsed'] =  gun_violence['gun_stolen_parsed'].str.replace('::', ': ')
gun_violence['gun_stolen_parsed']

gun_violence['gun_stolen_parsed'] = gun_violence['gun_stolen_parsed'].str.replace('|', ', ')

# %%
gun_violence['participant_gender_parsed'] =  gun_violence['participant_gender'].str.replace('\|\|', ', ')

gun_violence['participant_gender_parsed'] = gun_violence['participant_gender_parsed'].str.replace('::', ': ')
gun_violence['participant_gender']

# %%
gun_violence['participant_status_parsed'] =  gun_violence['participant_status'].str.replace('\|\|', ', ')

gun_violence['participant_status_parsed'] = gun_violence['participant_status_parsed'].str.replace('::', ': ')
gun_violence['participant_status_parsed']

# %%
gun_violence['participant_age_group_parsed'] =  gun_violence['participant_age_group'].str.replace('\|\|', ', ')

gun_violence['participant_age_group_parsed'] = gun_violence['participant_age_group_parsed'].str.replace('::', ': ')
gun_violence['participant_age_group_parsed']

# %%
gun_violence['participant_type_parsed'] =  gun_violence['participant_type'].str.replace('\|\|', ', ')

gun_violence['participant_type_parsed'] = gun_violence['participant_type_parsed'].str.replace('::', ': ')
gun_violence['participant_type_parsed']

# %%
gun_violence['participant_name_parsed'] =  gun_violence['participant_name'].str.replace('\|\|', ', ')

gun_violence['participant_name_parsed'] = gun_violence['participant_name_parsed'].str.replace('::', ': ')
gun_violence['participant_name_parsed']
gun_violence
